# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
df = pd.read_csv("Copy of sonar data.csv")

# %%
df
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#      0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0    0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1    0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2    0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3    0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4    0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 203  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 204  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 205  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 206  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#      0.0090  0.0032  R
# 0    0.0052  0.0044  R
# 1    0.0095  0.0078  R
# 2    0.0040  0.0117  R
# 3    0.0107  0.0094  R
# 4    0.0051  0.0062  R
# ..      ...     ... ..
# 202  0.0193  0.0157  M
# 203  0.0062  0.0067  M
# 204  0.0077  0.0031  M
# 205  0.0036  0.0048  M
# 206  0.0061  0.0115  M
#
# [207 rows x 61 columns]

# %%
df.head()
# Out:
#    0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4  0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
#
#    0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4  0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
#
#    0.0090  0.0032  R
# 0  0.0052  0.0044  R
# 1  0.0095  0.0078  R
# 2  0.0040  0.0117  R
# 3  0.0107  0.0094  R
# 4  0.0051  0.0062  R
#
# [5 rows x 61 columns]

# %%
df.R.value_counts()
# Out:
# M    111
# R     96
# Name: R, dtype: int64

# %%
x = df.drop("R", axis = 1)

# %%
y =df.R

# %%
x_train,x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
print(x.shape, x_train.shape, x_test.shape)
# Out:
# (207, 60) (165, 60) (42, 60)

# %%
y
# Out:
# 0      R
# 1      R
# 2      R
# 3      R
# 4      R
#       ..
# 202    M
# 203    M
# 204    M
# 205    M
# 206    M
# Name: R, Length: 207, dtype: object

# %%
model.predict(x_train)
# Out:
# array(['R', 'M', 'M', 'R', 'R', 'R', 'R', 'M', 'R', 'R', 'M', 'R', 'R',
#        'R', 'M', 'M', 'M', 'R', 'M', 'R', 'M', 'R', 'R', 'M', 'M', 'R',
#        'M', 'M', 'M', 'M', 'R', 'R', 'M', 'M', 'M', 'M', 'M', 'R', 'M',
#        'R', 'R', 'M', 'M', 'R', 'R', 'M', 'M', 'R', 'M', 'R', 'R', 'M',
#        'M', 'M', 'R', 'R', 'M', 'M', 'M', 'R', 'M', 'M', 'R', 'R', 'R',
#        'M', 'M', 'R', 'R', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'R', 'R',
#        'R', 'R', 'R', 'M', 'R', 'M', 'R', 'M', 'R', 'M', 'M', 'M', 'M',
#        'R', 'M', 'M', 'R', 'M', 'M', 'R', 'M', 'M', 'R', 'M', 'R', 'R',
#        'R', 'M', 'M', 'M', 'M', 'R', 'R', 'M', 'M', 'M', 'R', 'R', 'R',
#        'M', 'M', 'M', 'M', 'R', 'M', 'R', 'M', 'R', 'M', 'M', 'M', 'R',
#        'R', 'M', 'M', 'M', 'M', 'R', 'M', 'M', 'R', 'R', 'R', 'M', 'R',
#        'M', 'M', 'M', 'R', 'M', 'R', 'M', 'M', 'R', 'R', 'M', 'R', 'R',
#        'M', 'R', 'M', 'M', 'R', 'M', 'R', 'M', 'M'], dtype=object)

# %%
accuracy = model.score(x_train, y_train)

# %%
print(f"the accuracy of training data is {accuracy} ")
# Out:
# the accuracy of training data is 0.8424242424242424

# %%
model.predict(x_test)
# Out:
# array(['M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'M', 'R', 'M',
#        'R', 'M', 'R', 'M', 'M', 'R', 'R', 'M', 'R', 'R', 'R', 'M', 'M',
#        'R', 'M', 'R', 'M', 'M', 'R', 'M', 'R', 'R', 'R', 'R', 'M', 'M',
#        'M', 'R', 'M'], dtype=object)

# %%
accuracy_testing = model.score(x_test, y_test)

# %%
print(f"the accuracy of testing data is {accuracy_testing}")
# Out:
# the accuracy of testing data is 0.8095238095238095

# %%
df
# Out:
#      0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109  \
# 0    0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 1    0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 2    0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 3    0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
# 4    0.0286  0.0453  0.0277  0.0174  0.0384  0.0990  0.1201  0.1833  0.2105
# ..      ...     ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.0187  0.0346  0.0168  0.0177  0.0393  0.1630  0.2028  0.1694  0.2328
# 203  0.0323  0.0101  0.0298  0.0564  0.0760  0.0958  0.0990  0.1018  0.1030
# 204  0.0522  0.0437  0.0180  0.0292  0.0351  0.1171  0.1257  0.1178  0.1258
# 205  0.0303  0.0353  0.0490  0.0608  0.0167  0.1354  0.1465  0.1123  0.1945
# 206  0.0260  0.0363  0.0136  0.0272  0.0214  0.0338  0.0655  0.1400  0.1843
#
#      0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  \
# 0    0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 1    0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 2    0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 3    0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
# 4    0.3039  ...  0.0045  0.0014  0.0038  0.0013  0.0089  0.0057  0.0027
# ..      ...  ...     ...     ...     ...     ...     ...     ...     ...
# 202  0.2684  ...  0.0116  0.0098  0.0199  0.0033  0.0101  0.0065  0.0115
# 203  0.2154  ...  0.0061  0.0093  0.0135  0.0063  0.0063  0.0034  0.0032
# 204  0.2529  ...  0.0160  0.0029  0.0051  0.0062  0.0089  0.0140  0.0138
# 205  0.2354  ...  0.0086  0.0046  0.0126  0.0036  0.0035  0.0034  0.0079
# 206  0.2354  ...  0.0146  0.0129  0.0047  0.0039  0.0061  0.0040  0.0036
#
#      0.0090  0.0032  R
# 0    0.0052  0.0044  R
# 1    0.0095  0.0078  R
# 2    0.0040  0.0117  R
# 3    0.0107  0.0094  R
# 4    0.0051  0.0062  R
# ..      ...     ... ..
# 202  0.0193  0.0157  M
# 203  0.0062  0.0067  M
# 204  0.0077  0.0031  M
# 205  0.0036  0.0048  M
# 206  0.0061  0.0115  M
#
# [207 rows x 61 columns]

# %%
input_data = (0.0307,0.0523,0.0653,0.0521,0.0611,0.0577,0.0665,0.0664,0.1460,0.2792,0.3877,0.4992,0.4981,0.4972,0.5607,0.7339,0.8230,0.9173,0.9975,0.9911,0.8240,0.6498,0.5980,0.4862,0.3150,0.1543,0.0989,0.0284,0.1008,0.2636,0.2694,0.2930,0.2925,0.3998,0.3660,0.3172,0.4609,0.4374,0.1820,0.3376,0.6202,0.4448,0.1863,0.1420,0.0589,0.0576,0.0672,0.0269,0.0245,0.0190,0.0063,0.0321,0.0189,0.0137,0.0277,0.0152,0.0052,0.0121,0.0124,0.0055)

# changing the input_data to a numpy array
input_data_as_numpy_array = np.asarray(input_data)

# reshape the np array as we are predicting for one instance
input_data_reshaped = input_data_as_numpy_array.reshape(1,-1)

prediction = model.predict(input_data_reshaped)
print(prediction)

if (prediction[0]=='R'):
  print('The object is a Rock')
else:
  print('The object is a mine')
# Out:
# ['M']
# The object is a mine
# C:\Users\ahmedrammers\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
